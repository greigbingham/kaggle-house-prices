# %% [markdown]
# # House Prices
#
# #### Import Data

# %%
import pandas as pd

# %%
house_prices_train = pd.read_csv("train.csv")
house_prices_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_prices_train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
house_prices_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
house_prices_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
house_prices_train.mean()
# Out:
# C:\Users\GREIGB~1\AppData\Local\Temp/ipykernel_50544/776367451.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   house_prices_train.mean()
# Id                  730.500000
# MSSubClass           56.897260
# LotFrontage          70.049958
# LotArea           10516.828082
# OverallQual           6.099315
# OverallCond           5.575342
# YearBuilt          1971.267808
# YearRemodAdd       1984.865753
# MasVnrArea          103.685262
# BsmtFinSF1          443.639726
# BsmtFinSF2           46.549315
# BsmtUnfSF           567.240411
# TotalBsmtSF        1057.429452
# 1stFlrSF           1162.626712
# 2ndFlrSF            346.992466
# LowQualFinSF          5.844521
# GrLivArea          1515.463699
# BsmtFullBath          0.425342
# BsmtHalfBath          0.057534
# FullBath              1.565068
# ...

# %%
import matplotlib.pyplot as plt

house_prices_train["SalePrice"].plot()
# Out:
# <AxesSubplot:>

# %%
house_prices_train["SalePrice"].hist()
# Out:
# <AxesSubplot:>

# %%
house_prices_train["SalePrice"].mean()
# Out:
# 180921.19589041095

# %%
house_prices_train.corr
# Out:
# <bound method DataFrame.corr of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
corr_with_sale_price = house_prices_train[house_prices_train.columns[1:]].corr()['SalePrice'][:-1]
corr_with_sale_price
# Out:
# MSSubClass      -0.084284
# LotFrontage      0.351799
# LotArea          0.263843
# OverallQual      0.790982
# OverallCond     -0.077856
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.477493
# BsmtFinSF1       0.386420
# BsmtFinSF2      -0.011378
# BsmtUnfSF        0.214479
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# 2ndFlrSF         0.319334
# LowQualFinSF    -0.025606
# GrLivArea        0.708624
# BsmtFullBath     0.227122
# BsmtHalfBath    -0.016844
# FullBath         0.560664
# HalfBath         0.284108
# BedroomAbvGr     0.168213
# KitchenAbvGr    -0.135907
# TotRmsAbvGrd     0.533723
# Fireplaces       0.466929
# GarageYrBlt      0.486362
# GarageCars       0.640409
# GarageArea       0.623431
# WoodDeckSF       0.324413
# OpenPorchSF      0.315856
# EnclosedPorch   -0.128578
# 3SsnPorch        0.044584
# ScreenPorch      0.111447
# PoolArea         0.092404
# MiscVal         -0.021190
# MoSold           0.046432
# ...

# %%
corr_with_sale_price.to_csv("corr_with_sale_price.csv")

# %%
len(corr_with_sale_price)
# Out:
# 36

# %%
len(house_prices_train.columns)
# Out:
# 81

# %%
house_prices_train.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
cat_features = list(house_prices_train.select_dtypes(include=['object']).columns)
cat_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
cat_features = list(house_prices_train.select_dtypes(include=['object']).columns)

# %%
# Getting data ready
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
#from sklearn.impute import SimpleImputer - not used here
from sklearn.preprocessing import OneHotEncoder

# Modelling
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.metrics import mean_squared_error

np.random.seed(17)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\GREIGB~1\AppData\Local\Temp/ipykernel_50544/3638128337.py in <module>
#      12 from sklearn.metrics import mean_squared_error
#      13
# ---> 14 np.random.seed(17)
#
# NameError: name 'np' is not defined

# %%
#convert objects to numbers
categorical_transformer = Pipeline(steps=[
            ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

preprocessor = ColumnTransformer(
                transformers=[
                    ("cat", categorical_transformer, cat_features)
                ]
)

# %%
#Create a model
model = Pipeline(steps=[("preprocessor", preprocessor),
                        ("model", RandomForestRegressor())])

# %%
#Split data
X = house_prices_train.drop("SalePrice", axis=1)
y = house_prices_train["SalePrice"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Fit and score the model
model.fit(X_train, y_train)
model.score(X_test, y_test)

#mean_squared_error(X_test, y_test, squared=True)
# Out:
# 0.7278050584729431

# %%
len(y_test)
# Out:
# 292

# %%
actual_test_set = pd.read_csv("test.csv")
len(actual_test_set)
# Out:
# 1459

# %%
actual_test_set.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 1454         Lvl    AllPub  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
actual_preds = model.predict(actual_test_set)
len(actual_preds)
# Out:
# 1459

# %%
import numpy

numpy.savetxt("submission2.csv", actual_preds, delimiter=",")

# %%
y_test
# Out:
# 1279     68400
# 1245    178000
# 1206    107000
# 118     320000
# 895     140000
#          ...
# 666     129000
# 1309    179200
# 161     412500
# 784     128000
# 1006    163500
# Name: SalePrice, Length: 292, dtype: int64

# %%
#X2 = house_prices_train[["OverallQual","GrLivArea","GarageCars","GarageArea","TotalBsmtSF",
#                   "1stFlrSF","FullBath","TotRmsAbvGrd","YearBuilt","YearRemodAdd"]
#]

X2 = house_prices_train[["OverallQual","GrLivArea",
                    "1stFlrSF","FullBath","TotRmsAbvGrd","YearBuilt","YearRemodAdd"]
]

X2
# Out:
#       OverallQual  GrLivArea  1stFlrSF  FullBath  TotRmsAbvGrd  YearBuilt  \
# 0               7       1710       856         2             8       2003
# 1               6       1262      1262         2             6       1976
# 2               7       1786       920         2             6       2001
# 3               7       1717       961         1             7       1915
# 4               8       2198      1145         2             9       2000
# ...           ...        ...       ...       ...           ...        ...
# 1455            6       1647       953         2             7       1999
# 1456            6       2073      2073         2             7       1978
# 1457            7       2340      1188         2             9       1941
# 1458            5       1078      1078         1             5       1950
# 1459            5       1256      1256         1             6       1965
#
#       YearRemodAdd
# 0             2003
# 1             1976
# ...

# %%
#Create a model
np.random.seed(17)
model = Pipeline(steps=[("model", RandomForestRegressor())])

# %%
cat_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
#actual_test_set2 = actual_test_set[["OverallQual","GrLivArea","GarageCars","GarageArea","TotalBsmtSF",
#                    "1stFlrSF","FullBath","TotRmsAbvGrd","YearBuilt","YearRemodAdd"]
#]

actual_test_set2 = actual_test_set[["OverallQual","GrLivArea",
                    "1stFlrSF","FullBath","TotRmsAbvGrd","YearBuilt","YearRemodAdd"]
]

# %%
X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size=0.2)

# Fit and score the model
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.8394551639131855

# %%
actual_test_set2
# Out:
#       OverallQual  GrLivArea  1stFlrSF  FullBath  TotRmsAbvGrd  YearBuilt  \
# 0               5        896       896         1             5       1961
# 1               6       1329      1329         1             6       1958
# 2               5       1629       928         2             6       1997
# 3               6       1604       926         2             7       1998
# 4               8       1280      1280         2             5       1992
# ...           ...        ...       ...       ...           ...        ...
# 1454            4       1092       546         1             5       1970
# 1455            4       1092       546         1             6       1970
# 1456            5       1224      1224         1             7       1960
# 1457            5        970       970         1             6       1992
# 1458            7       2000       996         2             9       1993
#
#       YearRemodAdd
# 0             1961
# 1             1958
# ...

# %%
numpy.savetxt("actual_test_set2.csv", actual_test_set2, delimiter=",")

# %%
actual_preds = model.predict(actual_test_set2)

numpy.savetxt("submission3.csv", actual_preds, delimiter=",")

# %%
output_df = pd.DataFrame()

# %%
output_df["Id"] = list(range(1461,2920))
output_df["SalePrice"] = actual_preds

output_df.head()
# Out:
#      Id  SalePrice
# 0  1461  114529.08
# 1  1462  144609.00
# 2  1463  168204.90
# 3  1464  181379.00
# 4  1465  185173.00

# %%
output_df.to_csv('submission_file_withid3.csv', index=False)
